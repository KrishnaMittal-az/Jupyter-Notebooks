# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , confusion_matrix , accuracy_score

# %%
data = pd.read_csv('D:\\PycharmProjects\\ML Algo\\Jup notebooks\\CSV\\iot_device_data.csv')

# %%
print(data.head(30))
# Out:
#     temperature   humidity     pressure  vibration  status
# 0     27.483571  63.993554  1006.248217   0.046096  normal
# 1     24.308678  59.246337  1011.554813   0.569807  normal
# 2     28.238443  50.596304  1005.075801   0.793197  normal
# 3     32.615149  43.530632  1009.920385   1.943844  faulty
# 4     23.829233  56.982233   994.063853   1.278277  normal
# 5     23.829315  53.934854  1015.132937   0.332259  normal
# 6     32.896064  58.951932  1013.012055   1.243018  normal
# 7     28.837174  56.351718  1004.829114   0.226348  normal
# 8     22.652628  60.495527  1019.592457   1.541346  normal
# 9     27.712800  44.647648  1022.375701   0.764438  normal
# 10    22.682912  63.173941   996.924401   0.953182  normal
# 11    22.671351  51.975996  1005.372752   1.662898  normal
# 12    26.209811  70.752609  1005.308577   0.356418  normal
# 13    15.433599  43.108122  1003.600969   0.301441  normal
# 14    16.375411  67.359638  1021.294748   0.708200  normal
# 15    22.188562  51.979108  1011.061739   1.519189  normal
# 16    19.935844  43.485820  1010.354852   0.240327  normal
# 17    26.571237  45.161142   992.961376  -0.416078  normal
# 18    20.459880  46.796527  1019.354180   0.774421  normal
# 19    17.938481  54.241659  1000.607416   1.275870  normal
# 20    32.328244  55.228355  1013.599326   1.600131  faulty
# 21    23.871118  44.263000  1015.773769   0.768419  normal
# 22    25.337641  49.756454  1026.606586   0.794287  normal
# 23    17.876259  71.422704   999.911796   1.576950  normal
# 24    22.278086  67.275432   982.804878   0.065129  normal
# 25    25.554613  54.363237  1014.838495   0.805740  normal
# 26    19.245032  50.380035  1031.005112   1.095212  normal
# 27    26.878490  51.200313  1025.389464   1.224609  normal
# 28    21.996807  56.135180  1015.096594   0.745097  normal
# 29    23.541531  39.772074  1008.083638   1.017221  normal

# %%
X = data[['temperature', 'humidity' , 'pressure' , 'vibration']]
Y = data['status']

# %% [markdown]
# Convert Categorical into numerical (if necessary)

# %%
y = pd.factorize(Y)[0]

# %% [markdown]
# Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %% [markdown]
# Initialize random forest classifier

# %%
model = RandomForestClassifier(n_estimators=20, random_state=0)

# %% [markdown]
# Train the model

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)
